# %%
import pickle
import matplotlib.pyplot as plt

# %% [markdown]
# ## Faster RCNN

# %%
faster_100area = pickle.load(open("pickle/fasterrcnn_resnet50_area100_coco_validate_acc.pkl", "rb" ) )
faster_50area = pickle.load(open("pickle/fasterrcnn_resnet50_area50_coco_validate_acc.pkl", "rb"))
faster_ImageNet = pickle.load(open("pickle/fasterrcnn_resnet50_area100_imageNet_validate_acc.pkl", "rb"))

# %%
plt.title('Validation Accuracies for Faster-RCNN pretrained on COCO vs ImageNet')
plt.ylim(.45,.85)
plt.plot(faster_100area, label = "COCO")
plt.plot(faster_ImageNet, label = "ImageNet")
plt.legend(loc = "lower right")

# %%
plt.title('Validation Accuracies for Faster-RCNN on Nodule Area >=50 vs >=100')
plt.ylim(.6,.85)
plt.plot(faster_100area, label = "Area >=100")
plt.plot(faster_50area, label = "Area >=50")
plt.legend(loc = "lower right")

# %% [markdown]
# ## MaskRCNN Model Comparisons

# %%
mask_100area = pickle.load(open("pickle/maskrcnn_resnet50coco_100area_validate_acc.pkl", "rb" ) )
mask_50area = pickle.load(open("pickle/maskrcnn_resnet50coco_50area_validate_acc.pkl", "rb"))
mask_ImageNet = pickle.load(open("pickle/maskrcnn_resnet50ImageNet_100area_validate_acc.pkl", "rb"))

# %%
plt.title('Validation Accuracies for MaskRCNN pretrained on COCO vs ImageNet')
plt.ylim(.45,.85)
plt.plot(mask_100area, label = "COCO")
plt.plot(mask_ImageNet, label = "ImageNet")
plt.legend(loc = "lower right")

# %%
plt.title('Validation Accuracies for MaskRCNN on Nodule Area >=50 vs >=100')
plt.ylim(.6,.85)
plt.plot(mask_100area, label = "Area >=100")
plt.plot(mask_50area, label = "Area >=50")
plt.legend(loc = "lower right")
