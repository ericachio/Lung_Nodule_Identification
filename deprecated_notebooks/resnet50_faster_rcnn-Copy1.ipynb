# %%
import torchvision
import torch
import torch.nn as nn
import numpy as np
from torch import optim
from torch.utils.data import Dataset, DataLoader
import pandas as pd
from sklearn.model_selection import train_test_split
import os
from skimage import io
import time
import ast 
from PIL import *
from torchvision import transforms
import cv2
import matplotlib.pyplot as plt

# %%
if torch.cuda.is_available:
    device = torch.device('cuda')
else:
    device = torch.device('cpu')

# %%
# subset / old csv
# df = pd.read_csv('temp.csv')

# area larger than 1000
# df = pd.read_csv('area_larger_than_1000.csv')

# full dataset 
df = pd.read_csv('large_nodules_png_bounding_box.csv')

# subset of dataset (25%)
# _ , X_random, = train_test_split(df, test_size=0.25, random_state=0)
# X_random.to_csv('subset.csv',index=False)
# df = X_random

df
# Out:
#                                                    path   imageName  \
# 0     /scratch/ebc308/tcia/data_png/LIDC-IDRI/LIDC-I...  000059.png
# 1     /scratch/ebc308/tcia/data_png/LIDC-IDRI/LIDC-I...  000008.png
# 2     /scratch/ebc308/tcia/data_png/LIDC-IDRI/LIDC-I...  000109.png
# 3     /scratch/ebc308/tcia/data_png/LIDC-IDRI/LIDC-I...  000063.png
# 4     /scratch/ebc308/tcia/data_png/LIDC-IDRI/LIDC-I...  000005.png
# ...                                                 ...         ...
# 9395  /scratch/ebc308/tcia/data_png/LIDC-IDRI/LIDC-I...  000017.png
# 9396  /scratch/ebc308/tcia/data_png/LIDC-IDRI/LIDC-I...  000082.png
# 9397  /scratch/ebc308/tcia/data_png/LIDC-IDRI/LIDC-I...  000133.png
# 9398  /scratch/ebc308/tcia/data_png/LIDC-IDRI/LIDC-I...  000051.png
# 9399  /scratch/ebc308/tcia/data_png/LIDC-IDRI/LIDC-I...  000113.png
#
#                                          SOPInstanceUID  \
# 0     1.3.6.1.4.1.14519.5.2.1.6279.6001.319084926500...
# 1     1.3.6.1.4.1.14519.5.2.1.6279.6001.749728215582...
# 2     1.3.6.1.4.1.14519.5.2.1.6279.6001.327906493223...
# 3     1.3.6.1.4.1.14519.5.2.1.6279.6001.230680133701...
# 4     1.3.6.1.4.1.14519.5.2.1.6279.6001.212532866259...
# ...                                                 ...
# 9395  1.3.6.1.4.1.14519.5.2.1.6279.6001.323491922755...
# 9396  1.3.6.1.4.1.14519.5.2.1.6279.6001.276843939440...
# 9397  1.3.6.1.4.1.14519.5.2.1.6279.6001.207293484767...
# 9398  1.3.6.1.4.1.14519.5.2.1.6279.6001.518873247105...
# 9399  1.3.6.1.4.1.14519.5.2.1.6279.6001.195509175412...
#
#                                boxes  areas
# 0     [[165.0, 140.0, 199.0, 161.0]]  714.0
# 1     [[167.0, 134.0, 201.0, 160.0]]  884.0
# 2     [[167.0, 134.0, 202.0, 161.0]]  945.0
# 3     [[168.0, 135.0, 201.0, 160.0]]  825.0
# 4     [[180.0, 133.0, 200.0, 154.0]]  420.0
# ...                              ...    ...
# 9395  [[373.0, 352.0, 384.0, 364.0]]  132.0
# 9396  [[346.0, 350.0, 361.0, 361.0]]  165.0
# 9397  [[345.0, 351.0, 358.0, 361.0]]  130.0
# 9398  [[374.0, 354.0, 384.0, 362.0]]   80.0
# 9399  [[344.0, 351.0, 357.0, 362.0]]  143.0
#
# [9400 rows x 5 columns]

# %%
# split dataset into 60, 20, 20 
train_data, test_data = train_test_split(df, test_size=0.40, random_state=2020)
valid_data, test_data = train_test_split(test_data, test_size=0.50, random_state=2020)
train_data.index = np.arange(len(train_data))
valid_data.index = np.arange(len(valid_data))
test_data.index = np.arange(len(test_data))

# %%
train_data.to_csv("large_nodules_train.csv", index=False)
valid_data.to_csv("large_nodules_valid.csv", index=False)
test_data.to_csv("large_nodules_test.csv", index=False)

# %%
from torchvision import transforms
# torchvision models are trained on input images normalized to [0 1] range .ToPILImage() function achives this
# additional normalization is required see: http://pytorch.org/docs/master/torchvision/models.html

train_transform = transforms.Compose([
        transforms.ToPILImage(),
        transforms.RandomResizedCrop(896),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])])

validation_transform = transforms.Compose([
        transforms.ToPILImage(),
        transforms.CenterCrop(896),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])])

class Faster_RCNN_Dataloader(Dataset):
    """Chest X-ray dataset from https://nihcc.app.box.com/v/ChestXray-NIHCC."""

    def __init__(self, csv_file, transform=None):
        """
        Args:
            csv_file (string): Path to the csv file filename information.
            root_dir (string): Directory with all the images.
            transform (callable, optional): Optional transform to be applied
                on a sample.
        """
        self.data_frame = pd.read_csv(csv_file)
        self.transform = transform

    def __len__(self):
        return len(self.data_frame)

    def __getitem__(self, idx):
        
        # get image path
        img_name = (self.data_frame.iloc[idx, 0])
        
        # open image 
        image = io.imread(img_name)
        
        # 3 channels
        if len(image.shape) > 2 and image.shape[2] == 4:
            image = image[:,:,0]       
        image = np.repeat(image[None,...],3,axis=0)
        
        # transform image? 
        if self.transform:
            image = self.transform(np.uint8(image))

        d = {}
        d['boxes'] = torch.FloatTensor(ast.literal_eval(self.data_frame.iloc[idx, 3]))
        d['labels'] = torch.ones([1], dtype=torch.int64)

        return image, d

# change dataloader output to lists.
def pad_collate(batch):
    (xx, yy) = zip(*batch)
    return list(xx), list(yy)

# %%
train_df_path = 'large_nodules_train.csv'
validate_df_path = 'large_nodules_valid.csv'
test_df_path = 'large_nodules_test.csv'

transformed_dataset = {'train': Faster_RCNN_Dataloader(train_df_path, transform=train_transform),
                       'validate':Faster_RCNN_Dataloader(validate_df_path, transform=validation_transform),
                       'test':Faster_RCNN_Dataloader(test_df_path)}
bs = 8

dataloader = {x: DataLoader(transformed_dataset[x], batch_size=bs,
                        shuffle=True, collate_fn = pad_collate, num_workers=0) for x in ['train', 'validate','test']}
data_sizes ={x: len(transformed_dataset[x]) for x in ['train', 'validate','test']}


# one dataloader / phase, may be too memory intensive...

# train_dataset = {'train': Faster_RCNN_Dataloader(train_df_path, transform=train_transform)}
# validate_dataset = {'validate': Faster_RCNN_Dataloader(validate_df_path, transform=validation_transform)}
# test_dataset = {'test': Faster_RCNN_Dataloader(test_df_path)}

# bs = 16 #if bigger, running out of memory in p100

# train_dataloader = {x : DataLoader(train_dataset[x], batch_size=bs,
#                         shuffle=True,collate_fn = pad_collate, num_workers=0) for x in ['train']}
# validate_dataloader = {x : DataLoader(validate_dataset[x], batch_size=bs,
#                         shuffle=True,collate_fn = pad_collate, num_workers=0) for x in ['validate']}
# test_dataloader = {x : DataLoader(test_dataset[x], batch_size=bs,
#                         shuffle=True,collate_fn = pad_collate, num_workers=0) for x in ['test']}
# data_sizes ={len(dataset[x]) for x in ['train']}

# %%
# check if dataloader loaded correctly
# images1, targets1 = next(iter(train_dataloader['train']))
# images2, targets2 = next(iter(validate_dataloader['validate']))
# images3, targets3 = next(iter(test_dataloader['test']))

# to check dim of list dataloader
# len(images) = batch
# len(images[0]) = channel
# len(images[0]) = height
# len(images[0]) = width
images4, targets4 = next(iter(dataloader['train']))
len(images4[0])
# Out:
# 3

# %%
import torchvision
from torchvision.models.detection.faster_rcnn import FastRCNNPredictor

# load a model pre-trained pre-trained on COCO
model = torchvision.models.detection.fasterrcnn_resnet50_fpn(pretrained=True)

# replace the classifier with a new one, that has
# num_classes which is user-defined
num_classes = 2  # 1 class (nodule) + background

# get number of input features for the classifier
in_features = model.roi_heads.box_predictor.cls_score.in_features

# replace the pre-trained head with a new one
model.roi_heads.box_predictor = FastRCNNPredictor(in_features, num_classes)

# %%
from torchvision.models.detection import FasterRCNN
from torchvision.models.detection.rpn import AnchorGenerator

# # load a pre-trained model for classification and return
# # only the features
# backbone = torchvision.models.mobilenet_v2(pretrained=True).features
backbone = torchvision.models.vgg16(pretrained=True).features

# # FasterRCNN needs to know the number of
# # output channels in a backbone. For mobilenet_v2, it's 1280
# # so we need to add it here
# backbone.out_channels = 1280
backbone.out_channels = 512

# # let's make the RPN generate 5 x 3 anchors per spatial
# # location, with 5 different sizes and 3 different aspect
# # ratios. We have a Tuple[Tuple[int]] because each feature
# # map could potentially have different sizes and
# # aspect ratios
anchor_generator = AnchorGenerator(sizes=((32, 64, 128, 256, 512),),
                                   aspect_ratios=((0.5, 1.0, 2.0),))

# # let's define what are the feature maps that we will
# # use to perform the region of interest cropping, as well as
# # the size of the crop after rescaling.
# # if your backbone returns a Tensor, featmap_names is expected to
# # be [0]. More generally, the backbone should return an
# # OrderedDict[Tensor], and in featmap_names you can choose which
# # feature maps to use.
roi_pooler = torchvision.ops.MultiScaleRoIAlign(featmap_names=["0"],
                                                output_size=7,
                                                sampling_ratio=2)

model = FasterRCNN(backbone,
                   num_classes=2,
                   rpn_anchor_generator=anchor_generator,
                   box_roi_pool=roi_pooler).to(device)

# # tried to run not pretrained.
# model = torchvision.models.detection.fasterrcnn_resnet50_fpn(num_classes=2).to(device)

# for multiple nodes
torch.nn.DataParallel(model)


optimizer = torch.optim.SGD(model.parameters(), lr=1e-5,
                                momentum=0.9, weight_decay=1e-5)

# optimizer = torch.optim.SGD(model.parameters(), lr=0.00001, momentum=0.9, weight_decay=0.0005)

lambda_func = lambda epoch: 0.5 ** epoch
scheduler = optim.lr_scheduler.LambdaLR(optimizer, lr_lambda=lambda_func)

# unused 
cel = nn.MSELoss()

# %%
# move dict/lists to gpu 
def move_to(obj, device):
    if torch.is_tensor(obj):
        return obj.to(device)
    elif isinstance(obj, dict):
        res = {}
        for k, v in obj.items():
            res[k] = move_to(v, device)
        return res
    elif isinstance(obj, list):
        res = []
        for v in obj:
            res.append(move_to(v, device))
        return res
    else:
        raise TypeError("Invalid type for move_to")

# %%
# def calc_iou( gt_bbox, pred_bbox):
#     '''
#     This function takes the predicted bounding box and ground truth bounding box and 
#     return the IoU ratio
#     '''
    
#     # xmin ymax xmax ymin
#     x_topleft_gt, y_topleft_gt, x_bottomright_gt, y_bottomright_gt= gt_bbox
    
#     # x_topleft_p, y_topleft_p, x_bottomright_p, y_bottomright_p= pred_bbox
#     x1, y1, x2, y2 = pred_bbox
#     x_topleft_p = min(x1, x2)
#     y_topleft_p = max(y1, y2)
#     x_bottomright_p = max(x1, x2)
#     y_bottomright_p = min(y1, y2)
    
# #     if (x_topleft_gt > x_bottomright_gt) or (y_topleft_gt> y_bottomright_gt):
# # #         raise AssertionError("Ground Truth Bounding Box is not correct")
# #         return "Ground Truth Bounding Box is not correct"
# #     if (x_topleft_p > x_bottomright_p) or (y_topleft_p> y_bottomright_p):
# # #         raise AssertionError("Predicted Bounding Box is not correct",x_topleft_p, x_bottomright_p,y_topleft_p,y_bottomright_gt)
# #         return "Predicted Bounding Box is not correct"
         
#     #if the GT bbox and predcited BBox do not overlap then iou=0
#     if(x_bottomright_gt< x_topleft_p):
#         # If bottom right of x-coordinate  GT  bbox is less than or above the top left of x coordinate of  the predicted BBox
        
#         return 0.0
#     if(y_bottomright_gt> y_topleft_p):  # If bottom right of y-coordinate  GT  bbox is less than or above the top left of y coordinate of  the predicted BBox
        
#         return 0.0
#     if(x_topleft_gt> x_bottomright_p): # If bottom right of x-coordinate  GT  bbox is greater than or below the bottom right  of x coordinate of  the predcited BBox
        
#         return 0.0
#     if(y_topleft_gt< y_bottomright_p): # If bottom right of y-coordinate  GT  bbox is greater than or below the bottom right  of y coordinate of  the predcited BBox
        
#         return 0.0
    
#     # original code online calculation
# #     GT_bbox_area = (x_bottomright_gt -  x_topleft_gt + 1) * (  y_bottomright_gt -y_topleft_gt + 1)
# #     Pred_bbox_area =(x_bottomright_p - x_topleft_p + 1 ) * ( y_bottomright_p -y_topleft_p + 1)
    
#     # xmax - xmin , ymax - ymin
#     GT_bbox_area = (x_bottomright_gt -  x_topleft_gt + 1) * (  y_topleft_gt - y_bottomright_gt + 1)
#     Pred_bbox_area =(x_bottomright_p - x_topleft_p + 1 ) * ( y_topleft_p - y_bottomright_p + 1)
    
    
#     x_top_left =np.max([x_topleft_gt, x_topleft_p])
#     y_top_left = np.max([y_topleft_gt, y_topleft_p])
#     x_bottom_right = np.min([x_bottomright_gt, x_bottomright_p])
#     y_bottom_right = np.min([y_bottomright_gt, y_bottomright_p])
    
#     intersection_area = (x_bottom_right- x_top_left + 1) * (y_bottom_right-y_top_left  + 1)
    
#     union_area = (GT_bbox_area + Pred_bbox_area - intersection_area)
   
#     return intersection_area/union_area

# %%
def train_model(model, dataloader,optimizer, scheduler, loss_fn, num_epochs = 10, verbose = True):
    acc_dict = {'train':[]}
    loss_dict = {'train':[], 'validate':[]}
    best_acc = 0
    phases = ['train','validate']
    since = time.time()
    epochLossTrain = list()
#     epochAccTrain = list()
    epochLossValidate = list()
    epochAccValidate = list()
    for i in range(num_epochs):
        print('Epoch: {}/{}'.format(i, num_epochs-1))
        print('-'*10)
        losslist = []
        for p in phases:
            running_correct = 0
            running_loss = 0
            running_total = 0
            if p == 'train':
                model.train()
            else:
                model.eval()   
            num = 0 # calculate which batch --> enumerate not working
            for image, target in dataloader[p]:
                optimizer.zero_grad()
                # move data to gpu
                image = move_to(image,device)
                target = move_to(target,device)
                if (num % 25 == 0):
                    print('Train set | epoch: {:3d} | {:6d}/{:6d} batches'.format(i, num + 1, len(dataloader[p])))
                num = num + 1
                
                if p == 'train':
                    # loss = sum of all 4 losses returned
                    output = model((image), target)
                    loss = sum(loss for loss in output.values())
                else:
                    # helps with memory 
                    with torch.no_grad():
                        model.eval()  
                        output = model((image))
                        pred_score = [] # confidence score
                        pred_boxes = [] # bounding box
                        pred_class = [] # predicted class
                        maxIOUs = []
                        # loop through output (len(output) = batch size )
                        for j, out in enumerate(output):
                            # documentation: ['boxes'] = [x1, y1, x2, y2]
                            pred_boxes = [[i[0], i[1], i[2], i[3]] for i in list(out['boxes'].cpu().detach().numpy())]
                            pred_score = list(out['scores'].cpu().detach().numpy())
                            pred_class = [classes[i] for i in list(out['labels'].cpu().numpy())]
                            
                            # get correct label
                            # documentation: # 0 xmin, 1 ymin, 2 xmax, 3 ymax
                            t = target[j]['boxes'].cpu().detach().numpy()[0]
                            
                            # want to input: x min , y max, x max, y min
                            target_box =  [t[0],t[3],t[2],t[1]]
                            
                            # get index of max score - in theory want this one.
                            index = pred_score.index(max(pred_score))
                            
                            # right now, get iou of every predicted box
                            # and keep max iou 
                            iou = []
                            for ind in pred_boxes:
                                iou.append(calc_iou(target_box, ind))
                                maxIOUs.append(max(iou))
                        # sum max iou for each validate run to print out to see if above 0.0
                        epoch_acc = (sum(maxIOUs))
                # printing average loss / epoch
                num_imgs = len(image)
                running_loss += loss*num_imgs
                running_total += num_imgs
                
                if p == 'train':
                    loss.backward()
                    optimizer.step()
                    
            epoch_loss = float(running_loss/running_total)
            
            # keep epoch loss / accuracy (for validation)
            if p == 'train':
                epochLossTrain.append(epoch_loss)
#                 epochAccTrain.append(epoch_acc)
            if p == 'validate':
                epochLossValidate.append(epoch_loss)
                epochAccValidate.append(epoch_acc)
            if verbose or (i%10 == 0):
                if p == 'train':
                    print('Phase:{}, epoch loss: {:.4f}'.format(p, epoch_loss))
                if p == 'validate':
                    print('Phase:{}, epoch loss: {:.4f} | epoch accuracy: {:.4f}'.format(p, epoch_loss, epoch_acc))
            # old code
#             acc_dict[p].append(epoch_acc)
#             loss_dict[p].append(epoch_loss)      
#             if p == 'validate':
#                 if epoch_acc > best_acc:
#                     best_acc = epoch_acc
#                     best_model_wts = model.state_dict()
#             else:
            # schedule supposed to be under "else:" - not sure what it does...
            if scheduler:
                scheduler.step()
        
    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(time_elapsed // 60, time_elapsed % 60))
#     print('Best val acc: {:4f}'.format(best_acc))
    
#     model.load_state_dict(best_model_wts)
#     return model, acc_dict, loss_dict, epochLossTrain, epochLossValidate, epochAccTrain, epochAccValidate
    return model, acc_dict, loss_dict, epochLossTrain ,epochLossValidate, epochAccValidate

# %%
model, acc_dict, loss_dict, epochLossTrain,epochLossValidate,epochAccValidate = train_model(model, dataloader, optimizer, 
                                                                        scheduler, 
                                                                        cel, 
                                                                        num_epochs=100)
# Out:
# Epoch: 0/99
# ----------
# Train set | epoch:   0 |      1/   705 batches
# Train set | epoch:   0 |     26/   705 batches
# Train set | epoch:   0 |     51/   705 batches
# Train set | epoch:   0 |     76/   705 batches
# Train set | epoch:   0 |    101/   705 batches
# Train set | epoch:   0 |    126/   705 batches
# Train set | epoch:   0 |    151/   705 batches
# Train set | epoch:   0 |    176/   705 batches
# Train set | epoch:   0 |    201/   705 batches
# Train set | epoch:   0 |    226/   705 batches
# Train set | epoch:   0 |    251/   705 batches
# Train set | epoch:   0 |    276/   705 batches
# Train set | epoch:   0 |    301/   705 batches
# Train set | epoch:   0 |    326/   705 batches
# Train set | epoch:   0 |    351/   705 batches
# Train set | epoch:   0 |    376/   705 batches
# Train set | epoch:   0 |    401/   705 batches
# Train set | epoch:   0 |    426/   705 batches
# Train set | epoch:   0 |    451/   705 batches
# Train set | epoch:   0 |    476/   705 batches
# Train set | epoch:   0 |    501/   705 batches
# Train set | epoch:   0 |    526/   705 batches
# Train set | epoch:   0 |    551/   705 batches
# Train set | epoch:   0 |    576/   705 batches
# Train set | epoch:   0 |    601/   705 batches
# Train set | epoch:   0 |    626/   705 batches
# Train set | epoch:   0 |    651/   705 batches
# Train set | epoch:   0 |    676/   705 batches
# Train set | epoch:   0 |    701/   705 batches
# Phase:train, epoch loss: 0.3756
# Train set | epoch:   0 |      1/   235 batches
# Train set | epoch:   0 |     26/   235 batches
# Train set | epoch:   0 |     51/   235 batches
# Train set | epoch:   0 |     76/   235 batches
# Train set | epoch:   0 |    101/   235 batches
# Train set | epoch:   0 |    126/   235 batches
# Train set | epoch:   0 |    151/   235 batches
# Train set | epoch:   0 |    176/   235 batches
# Train set | epoch:   0 |    201/   235 batches
# Train set | epoch:   0 |    226/   235 batches
# Phase:validate, epoch loss: 0.0883 | epoch accuracy: 0.0000
# Epoch: 1/99
# ----------
# Train set | epoch:   1 |      1/   705 batches
# Train set | epoch:   1 |     26/   705 batches
# Train set | epoch:   1 |     51/   705 batches
# Train set | epoch:   1 |     76/   705 batches
# Train set | epoch:   1 |    101/   705 batches
# Train set | epoch:   1 |    126/   705 batches
# Train set | epoch:   1 |    151/   705 batches
# Train set | epoch:   1 |    176/   705 batches
# Train set | epoch:   1 |    201/   705 batches
# Train set | epoch:   1 |    226/   705 batches
# Train set | epoch:   1 |    251/   705 batches
# Train set | epoch:   1 |    276/   705 batches
# Train set | epoch:   1 |    301/   705 batches
# Train set | epoch:   1 |    326/   705 batches
# Train set | epoch:   1 |    351/   705 batches
# Train set | epoch:   1 |    376/   705 batches
# Train set | epoch:   1 |    401/   705 batches
# Train set | epoch:   1 |    426/   705 batches
# Train set | epoch:   1 |    451/   705 batches
# Train set | epoch:   1 |    476/   705 batches
# Train set | epoch:   1 |    501/   705 batches
# Train set | epoch:   1 |    526/   705 batches
# Train set | epoch:   1 |    551/   705 batches
# Train set | epoch:   1 |    576/   705 batches
# Train set | epoch:   1 |    601/   705 batches
# Train set | epoch:   1 |    626/   705 batches
# Train set | epoch:   1 |    651/   705 batches
# Train set | epoch:   1 |    676/   705 batches
# Train set | epoch:   1 |    701/   705 batches
# Phase:train, epoch loss: 0.0970
# Train set | epoch:   1 |      1/   235 batches
# Train set | epoch:   1 |     26/   235 batches
# Train set | epoch:   1 |     51/   235 batches
# Train set | epoch:   1 |     76/   235 batches
# Train set | epoch:   1 |    101/   235 batches
# Train set | epoch:   1 |    126/   235 batches
# Train set | epoch:   1 |    151/   235 batches
# Train set | epoch:   1 |    176/   235 batches
# Train set | epoch:   1 |    201/   235 batches
# Train set | epoch:   1 |    226/   235 batches
# Phase:validate, epoch loss: 0.0806 | epoch accuracy: 0.0000
# Epoch: 2/99
# ----------
# Train set | epoch:   2 |      1/   705 batches
# Train set | epoch:   2 |     26/   705 batches
# Train set | epoch:   2 |     51/   705 batches
# Train set | epoch:   2 |     76/   705 batches
# Train set | epoch:   2 |    101/   705 batches
# Train set | epoch:   2 |    126/   705 batches
# Train set | epoch:   2 |    151/   705 batches
# Train set | epoch:   2 |    176/   705 batches
# Train set | epoch:   2 |    201/   705 batches
# Train set | epoch:   2 |    226/   705 batches
# Train set | epoch:   2 |    251/   705 batches
# Train set | epoch:   2 |    276/   705 batches
# Train set | epoch:   2 |    301/   705 batches
# Train set | epoch:   2 |    326/   705 batches
# Train set | epoch:   2 |    351/   705 batches
# Train set | epoch:   2 |    376/   705 batches
# Train set | epoch:   2 |    401/   705 batches
# Train set | epoch:   2 |    426/   705 batches
# Train set | epoch:   2 |    451/   705 batches
# Train set | epoch:   2 |    476/   705 batches
# Train set | epoch:   2 |    501/   705 batches
# Train set | epoch:   2 |    526/   705 batches
# Train set | epoch:   2 |    551/   705 batches
# Train set | epoch:   2 |    576/   705 batches
# Train set | epoch:   2 |    601/   705 batches
# Train set | epoch:   2 |    626/   705 batches
# Train set | epoch:   2 |    651/   705 batches
# Train set | epoch:   2 |    676/   705 batches
# Train set | epoch:   2 |    701/   705 batches
# Phase:train, epoch loss: 0.0920
# Train set | epoch:   2 |      1/   235 batches
# Train set | epoch:   2 |     26/   235 batches
# Train set | epoch:   2 |     51/   235 batches
# Train set | epoch:   2 |     76/   235 batches
# Train set | epoch:   2 |    101/   235 batches
# Train set | epoch:   2 |    126/   235 batches
# Train set | epoch:   2 |    151/   235 batches
# Train set | epoch:   2 |    176/   235 batches
# Train set | epoch:   2 |    201/   235 batches
# Train set | epoch:   2 |    226/   235 batches
# Phase:validate, epoch loss: 0.0718 | epoch accuracy: 0.0000
# Epoch: 3/99
# ----------
# Train set | epoch:   3 |      1/   705 batches
# Train set | epoch:   3 |     26/   705 batches
# Train set | epoch:   3 |     51/   705 batches
# Train set | epoch:   3 |     76/   705 batches
# Train set | epoch:   3 |    101/   705 batches
# Train set | epoch:   3 |    126/   705 batches
# Train set | epoch:   3 |    151/   705 batches
# Train set | epoch:   3 |    176/   705 batches
# Train set | epoch:   3 |    201/   705 batches
# Train set | epoch:   3 |    226/   705 batches
# Train set | epoch:   3 |    251/   705 batches
# Train set | epoch:   3 |    276/   705 batches
# Train set | epoch:   3 |    301/   705 batches
# Train set | epoch:   3 |    326/   705 batches
# Train set | epoch:   3 |    351/   705 batches
# Train set | epoch:   3 |    376/   705 batches
# Train set | epoch:   3 |    401/   705 batches
# Train set | epoch:   3 |    426/   705 batches
# Train set | epoch:   3 |    451/   705 batches
# Train set | epoch:   3 |    476/   705 batches
# Train set | epoch:   3 |    501/   705 batches
# Train set | epoch:   3 |    526/   705 batches
# Train set | epoch:   3 |    551/   705 batches
# Train set | epoch:   3 |    576/   705 batches
# Train set | epoch:   3 |    601/   705 batches
# Train set | epoch:   3 |    626/   705 batches
# Train set | epoch:   3 |    651/   705 batches
# Train set | epoch:   3 |    676/   705 batches
# Train set | epoch:   3 |    701/   705 batches
# Phase:train, epoch loss: 0.0903
# Train set | epoch:   3 |      1/   235 batches
# Train set | epoch:   3 |     26/   235 batches
# Train set | epoch:   3 |     51/   235 batches
# Train set | epoch:   3 |     76/   235 batches
# Train set | epoch:   3 |    101/   235 batches
# Train set | epoch:   3 |    126/   235 batches
# Train set | epoch:   3 |    151/   235 batches
# Train set | epoch:   3 |    176/   235 batches
# Train set | epoch:   3 |    201/   235 batches
# Train set | epoch:   3 |    226/   235 batches
# Phase:validate, epoch loss: 0.0856 | epoch accuracy: 0.0000
# Epoch: 4/99
# ----------
# Train set | epoch:   4 |      1/   705 batches
# Train set | epoch:   4 |     26/   705 batches
# Train set | epoch:   4 |     51/   705 batches
# Train set | epoch:   4 |     76/   705 batches
# Train set | epoch:   4 |    101/   705 batches
# Train set | epoch:   4 |    126/   705 batches
# Train set | epoch:   4 |    151/   705 batches
# Train set | epoch:   4 |    176/   705 batches
# Train set | epoch:   4 |    201/   705 batches
# Train set | epoch:   4 |    226/   705 batches
# Train set | epoch:   4 |    251/   705 batches
# Train set | epoch:   4 |    276/   705 batches
# Train set | epoch:   4 |    301/   705 batches
# Train set | epoch:   4 |    326/   705 batches
# Train set | epoch:   4 |    351/   705 batches
# Train set | epoch:   4 |    376/   705 batches
# Train set | epoch:   4 |    401/   705 batches
# Train set | epoch:   4 |    426/   705 batches
# Train set | epoch:   4 |    451/   705 batches
# Train set | epoch:   4 |    476/   705 batches
# Train set | epoch:   4 |    501/   705 batches
# Train set | epoch:   4 |    526/   705 batches
# Train set | epoch:   4 |    551/   705 batches
# Train set | epoch:   4 |    576/   705 batches
# Train set | epoch:   4 |    601/   705 batches
# Train set | epoch:   4 |    626/   705 batches
# Train set | epoch:   4 |    651/   705 batches
# Train set | epoch:   4 |    676/   705 batches
# Train set | epoch:   4 |    701/   705 batches
# Phase:train, epoch loss: 0.0900
# Train set | epoch:   4 |      1/   235 batches
# Train set | epoch:   4 |     26/   235 batches
# Train set | epoch:   4 |     51/   235 batches
# Train set | epoch:   4 |     76/   235 batches
# Train set | epoch:   4 |    101/   235 batches
# Train set | epoch:   4 |    126/   235 batches
# Train set | epoch:   4 |    151/   235 batches
# Train set | epoch:   4 |    176/   235 batches
# Train set | epoch:   4 |    201/   235 batches
# Train set | epoch:   4 |    226/   235 batches
# Phase:validate, epoch loss: 0.0666 | epoch accuracy: 0.0000
# Epoch: 5/99
# ----------
# Train set | epoch:   5 |      1/   705 batches
# Train set | epoch:   5 |     26/   705 batches
# Train set | epoch:   5 |     51/   705 batches
# Train set | epoch:   5 |     76/   705 batches
# Train set | epoch:   5 |    101/   705 batches
# Train set | epoch:   5 |    126/   705 batches
# Train set | epoch:   5 |    151/   705 batches
# Train set | epoch:   5 |    176/   705 batches
# Train set | epoch:   5 |    201/   705 batches
# Train set | epoch:   5 |    226/   705 batches
# Train set | epoch:   5 |    251/   705 batches
# Train set | epoch:   5 |    276/   705 batches
# Train set | epoch:   5 |    301/   705 batches
# Train set | epoch:   5 |    326/   705 batches
# Train set | epoch:   5 |    351/   705 batches
# Train set | epoch:   5 |    376/   705 batches
# Train set | epoch:   5 |    401/   705 batches
# Train set | epoch:   5 |    426/   705 batches
# Train set | epoch:   5 |    451/   705 batches
# Train set | epoch:   5 |    476/   705 batches
# Train set | epoch:   5 |    501/   705 batches
# Train set | epoch:   5 |    526/   705 batches
# Train set | epoch:   5 |    551/   705 batches
# Train set | epoch:   5 |    576/   705 batches
# Train set | epoch:   5 |    601/   705 batches
# Train set | epoch:   5 |    626/   705 batches
# Train set | epoch:   5 |    651/   705 batches
# Train set | epoch:   5 |    676/   705 batches
# Train set | epoch:   5 |    701/   705 batches
# Phase:train, epoch loss: 0.0898
# Train set | epoch:   5 |      1/   235 batches
# Train set | epoch:   5 |     26/   235 batches
# Train set | epoch:   5 |     51/   235 batches
# Train set | epoch:   5 |     76/   235 batches
# Train set | epoch:   5 |    101/   235 batches
# Train set | epoch:   5 |    126/   235 batches
# Train set | epoch:   5 |    151/   235 batches
# Train set | epoch:   5 |    176/   235 batches
# Train set | epoch:   5 |    201/   235 batches
# Train set | epoch:   5 |    226/   235 batches
# Phase:validate, epoch loss: 0.0800 | epoch accuracy: 0.0000
# Epoch: 6/99
# ----------
# Train set | epoch:   6 |      1/   705 batches
# Train set | epoch:   6 |     26/   705 batches
# Train set | epoch:   6 |     51/   705 batches
# Train set | epoch:   6 |     76/   705 batches
# Train set | epoch:   6 |    101/   705 batches
# Train set | epoch:   6 |    126/   705 batches
# Train set | epoch:   6 |    151/   705 batches
# Train set | epoch:   6 |    176/   705 batches
# Train set | epoch:   6 |    201/   705 batches
# Train set | epoch:   6 |    226/   705 batches
# Train set | epoch:   6 |    251/   705 batches
# Train set | epoch:   6 |    276/   705 batches
# Train set | epoch:   6 |    301/   705 batches
# Train set | epoch:   6 |    326/   705 batches
# Train set | epoch:   6 |    351/   705 batches
# Train set | epoch:   6 |    376/   705 batches
# Train set | epoch:   6 |    401/   705 batches
# Train set | epoch:   6 |    426/   705 batches
# Train set | epoch:   6 |    451/   705 batches
# Train set | epoch:   6 |    476/   705 batches
# Train set | epoch:   6 |    501/   705 batches
# Train set | epoch:   6 |    526/   705 batches
# Train set | epoch:   6 |    551/   705 batches
# Train set | epoch:   6 |    576/   705 batches
# Train set | epoch:   6 |    601/   705 batches
# Train set | epoch:   6 |    626/   705 batches
# Train set | epoch:   6 |    651/   705 batches
# Train set | epoch:   6 |    676/   705 batches
# Train set | epoch:   6 |    701/   705 batches
# Phase:train, epoch loss: 0.0898
# Train set | epoch:   6 |      1/   235 batches
# Train set | epoch:   6 |     26/   235 batches
# Train set | epoch:   6 |     51/   235 batches
# Train set | epoch:   6 |     76/   235 batches
# Train set | epoch:   6 |    101/   235 batches
# Train set | epoch:   6 |    126/   235 batches
# Train set | epoch:   6 |    151/   235 batches
# Train set | epoch:   6 |    176/   235 batches
# Train set | epoch:   6 |    201/   235 batches
# Train set | epoch:   6 |    226/   235 batches
# Phase:validate, epoch loss: 0.0746 | epoch accuracy: 0.0000
# Epoch: 7/99
# ----------
# Train set | epoch:   7 |      1/   705 batches
# Train set | epoch:   7 |     26/   705 batches
# Train set | epoch:   7 |     51/   705 batches
# Train set | epoch:   7 |     76/   705 batches
# Train set | epoch:   7 |    101/   705 batches
# Train set | epoch:   7 |    126/   705 batches
# Train set | epoch:   7 |    151/   705 batches
# Train set | epoch:   7 |    176/   705 batches
# Train set | epoch:   7 |    201/   705 batches
# Train set | epoch:   7 |    226/   705 batches
# Train set | epoch:   7 |    251/   705 batches
# Train set | epoch:   7 |    276/   705 batches
# Train set | epoch:   7 |    301/   705 batches
# Train set | epoch:   7 |    326/   705 batches
# Train set | epoch:   7 |    351/   705 batches
# Train set | epoch:   7 |    376/   705 batches
# Train set | epoch:   7 |    401/   705 batches
# Train set | epoch:   7 |    426/   705 batches
# Train set | epoch:   7 |    451/   705 batches
# Train set | epoch:   7 |    476/   705 batches
# Train set | epoch:   7 |    501/   705 batches
# Train set | epoch:   7 |    526/   705 batches
# Train set | epoch:   7 |    551/   705 batches
# Train set | epoch:   7 |    576/   705 batches
# Train set | epoch:   7 |    601/   705 batches
# Train set | epoch:   7 |    626/   705 batches
# Train set | epoch:   7 |    651/   705 batches
# Train set | epoch:   7 |    676/   705 batches
# Train set | epoch:   7 |    701/   705 batches
# Phase:train, epoch loss: 0.0899
# Train set | epoch:   7 |      1/   235 batches
# Train set | epoch:   7 |     26/   235 batches
# Train set | epoch:   7 |     51/   235 batches
# Train set | epoch:   7 |     76/   235 batches
# Train set | epoch:   7 |    101/   235 batches
# Train set | epoch:   7 |    126/   235 batches
# Train set | epoch:   7 |    151/   235 batches
# Train set | epoch:   7 |    176/   235 batches
# Train set | epoch:   7 |    201/   235 batches
# Train set | epoch:   7 |    226/   235 batches
# Phase:validate, epoch loss: 0.1507 | epoch accuracy: 0.0000
# Epoch: 8/99
# ----------
# Train set | epoch:   8 |      1/   705 batches
# Train set | epoch:   8 |     26/   705 batches
# Train set | epoch:   8 |     51/   705 batches
# Train set | epoch:   8 |     76/   705 batches
# Train set | epoch:   8 |    101/   705 batches
# Train set | epoch:   8 |    126/   705 batches
# Train set | epoch:   8 |    151/   705 batches
# Train set | epoch:   8 |    176/   705 batches
# Train set | epoch:   8 |    201/   705 batches
# Train set | epoch:   8 |    226/   705 batches
# Train set | epoch:   8 |    251/   705 batches
# Train set | epoch:   8 |    276/   705 batches
# Train set | epoch:   8 |    301/   705 batches
# Train set | epoch:   8 |    326/   705 batches
# Train set | epoch:   8 |    351/   705 batches
# Train set | epoch:   8 |    376/   705 batches
# Train set | epoch:   8 |    401/   705 batches
# Train set | epoch:   8 |    426/   705 batches
# Train set | epoch:   8 |    451/   705 batches
# Train set | epoch:   8 |    476/   705 batches
# Train set | epoch:   8 |    501/   705 batches
# Train set | epoch:   8 |    526/   705 batches
# Train set | epoch:   8 |    551/   705 batches
# Train set | epoch:   8 |    576/   705 batches
# Train set | epoch:   8 |    601/   705 batches
# Train set | epoch:   8 |    626/   705 batches
# Train set | epoch:   8 |    651/   705 batches
# Train set | epoch:   8 |    676/   705 batches
# Train set | epoch:   8 |    701/   705 batches
# Phase:train, epoch loss: 0.0899
# Train set | epoch:   8 |      1/   235 batches
# Train set | epoch:   8 |     26/   235 batches
# Train set | epoch:   8 |     51/   235 batches
# Train set | epoch:   8 |     76/   235 batches
# Train set | epoch:   8 |    101/   235 batches
# Train set | epoch:   8 |    126/   235 batches
# Train set | epoch:   8 |    151/   235 batches
# Train set | epoch:   8 |    176/   235 batches
# Train set | epoch:   8 |    201/   235 batches
# Train set | epoch:   8 |    226/   235 batches
# Phase:validate, epoch loss: 0.0870 | epoch accuracy: 0.0000
# Epoch: 9/99
# ----------
# Train set | epoch:   9 |      1/   705 batches
# Train set | epoch:   9 |     26/   705 batches
# Train set | epoch:   9 |     51/   705 batches
# Train set | epoch:   9 |     76/   705 batches
# Train set | epoch:   9 |    101/   705 batches
# Train set | epoch:   9 |    126/   705 batches
# Train set | epoch:   9 |    151/   705 batches
# Train set | epoch:   9 |    176/   705 batches
# Train set | epoch:   9 |    201/   705 batches
# Train set | epoch:   9 |    226/   705 batches
# Train set | epoch:   9 |    251/   705 batches
# Train set | epoch:   9 |    276/   705 batches
# Train set | epoch:   9 |    301/   705 batches
# Train set | epoch:   9 |    326/   705 batches
# Train set | epoch:   9 |    351/   705 batches
# Train set | epoch:   9 |    376/   705 batches
# Train set | epoch:   9 |    401/   705 batches
# Train set | epoch:   9 |    426/   705 batches
# Train set | epoch:   9 |    451/   705 batches
# Train set | epoch:   9 |    476/   705 batches
# Train set | epoch:   9 |    501/   705 batches
# Train set | epoch:   9 |    526/   705 batches
# Train set | epoch:   9 |    551/   705 batches
# Train set | epoch:   9 |    576/   705 batches
# Train set | epoch:   9 |    601/   705 batches
# Train set | epoch:   9 |    626/   705 batches
# Train set | epoch:   9 |    651/   705 batches
# Train set | epoch:   9 |    676/   705 batches
# Train set | epoch:   9 |    701/   705 batches
# Phase:train, epoch loss: 0.0898
# Train set | epoch:   9 |      1/   235 batches
# Train set | epoch:   9 |     26/   235 batches
# Train set | epoch:   9 |     51/   235 batches
# Train set | epoch:   9 |     76/   235 batches
# Train set | epoch:   9 |    101/   235 batches
# Train set | epoch:   9 |    126/   235 batches
# Train set | epoch:   9 |    151/   235 batches
# Train set | epoch:   9 |    176/   235 batches
# Train set | epoch:   9 |    201/   235 batches
# Train set | epoch:   9 |    226/   235 batches
# Phase:validate, epoch loss: 0.0795 | epoch accuracy: 0.0000
# Epoch: 10/99
# ----------
# Train set | epoch:  10 |      1/   705 batches
# Train set | epoch:  10 |     26/   705 batches
# Train set | epoch:  10 |     51/   705 batches
# Train set | epoch:  10 |     76/   705 batches
# Train set | epoch:  10 |    101/   705 batches
# Train set | epoch:  10 |    126/   705 batches
# Train set | epoch:  10 |    151/   705 batches
# Train set | epoch:  10 |    176/   705 batches
# Train set | epoch:  10 |    201/   705 batches
# Train set | epoch:  10 |    226/   705 batches
# Train set | epoch:  10 |    251/   705 batches
# Train set | epoch:  10 |    276/   705 batches
# Train set | epoch:  10 |    301/   705 batches
# Train set | epoch:  10 |    326/   705 batches
# Train set | epoch:  10 |    351/   705 batches
# Train set | epoch:  10 |    376/   705 batches
# Train set | epoch:  10 |    401/   705 batches
# Train set | epoch:  10 |    426/   705 batches
# Train set | epoch:  10 |    451/   705 batches
# Train set | epoch:  10 |    476/   705 batches
# Train set | epoch:  10 |    501/   705 batches
# Train set | epoch:  10 |    526/   705 batches
# Train set | epoch:  10 |    551/   705 batches
# Train set | epoch:  10 |    576/   705 batches
# Train set | epoch:  10 |    601/   705 batches
# Train set | epoch:  10 |    626/   705 batches
# Train set | epoch:  10 |    651/   705 batches
# Train set | epoch:  10 |    676/   705 batches
# Train set | epoch:  10 |    701/   705 batches
# Phase:train, epoch loss: 0.0899
# Train set | epoch:  10 |      1/   235 batches
# Train set | epoch:  10 |     26/   235 batches
# Train set | epoch:  10 |     51/   235 batches
# Train set | epoch:  10 |     76/   235 batches
# Train set | epoch:  10 |    101/   235 batches
# Train set | epoch:  10 |    126/   235 batches
# Train set | epoch:  10 |    151/   235 batches
# Train set | epoch:  10 |    176/   235 batches
# Train set | epoch:  10 |    201/   235 batches
# Train set | epoch:  10 |    226/   235 batches
# Phase:validate, epoch loss: 0.1073 | epoch accuracy: 0.0000
# Epoch: 11/99
# ----------
# Train set | epoch:  11 |      1/   705 batches
# Train set | epoch:  11 |     26/   705 batches
# Train set | epoch:  11 |     51/   705 batches
# Train set | epoch:  11 |     76/   705 batches
# Train set | epoch:  11 |    101/   705 batches
# Train set | epoch:  11 |    126/   705 batches
# Train set | epoch:  11 |    151/   705 batches
# Train set | epoch:  11 |    176/   705 batches
# Train set | epoch:  11 |    201/   705 batches
# Train set | epoch:  11 |    226/   705 batches
# Train set | epoch:  11 |    251/   705 batches
# Train set | epoch:  11 |    276/   705 batches
# Train set | epoch:  11 |    301/   705 batches
# Train set | epoch:  11 |    326/   705 batches
# Train set | epoch:  11 |    351/   705 batches
# Train set | epoch:  11 |    376/   705 batches
# Train set | epoch:  11 |    401/   705 batches
# Train set | epoch:  11 |    426/   705 batches
# Train set | epoch:  11 |    451/   705 batches
# Train set | epoch:  11 |    476/   705 batches
# Train set | epoch:  11 |    501/   705 batches
# Train set | epoch:  11 |    526/   705 batches
# Train set | epoch:  11 |    551/   705 batches
# Train set | epoch:  11 |    576/   705 batches
# Train set | epoch:  11 |    601/   705 batches
# Train set | epoch:  11 |    626/   705 batches
# Train set | epoch:  11 |    651/   705 batches
# Train set | epoch:  11 |    676/   705 batches
# Train set | epoch:  11 |    701/   705 batches
# Phase:train, epoch loss: 0.0898
# Train set | epoch:  11 |      1/   235 batches
# Train set | epoch:  11 |     26/   235 batches
# Train set | epoch:  11 |     51/   235 batches
# Train set | epoch:  11 |     76/   235 batches
# Train set | epoch:  11 |    101/   235 batches
# Train set | epoch:  11 |    126/   235 batches
# Train set | epoch:  11 |    151/   235 batches
# Train set | epoch:  11 |    176/   235 batches
# Train set | epoch:  11 |    201/   235 batches
# Train set | epoch:  11 |    226/   235 batches
# Phase:validate, epoch loss: 0.2309 | epoch accuracy: 0.0000
# Epoch: 12/99
# ----------
# Train set | epoch:  12 |      1/   705 batches
# Train set | epoch:  12 |     26/   705 batches
# Train set | epoch:  12 |     51/   705 batches
# Train set | epoch:  12 |     76/   705 batches
# Train set | epoch:  12 |    101/   705 batches
# Train set | epoch:  12 |    126/   705 batches
# Train set | epoch:  12 |    151/   705 batches
# Train set | epoch:  12 |    176/   705 batches
# Train set | epoch:  12 |    201/   705 batches
# Train set | epoch:  12 |    226/   705 batches
# Train set | epoch:  12 |    251/   705 batches
# Train set | epoch:  12 |    276/   705 batches
# Train set | epoch:  12 |    301/   705 batches
# Train set | epoch:  12 |    326/   705 batches
# Train set | epoch:  12 |    351/   705 batches
# Train set | epoch:  12 |    376/   705 batches
# Train set | epoch:  12 |    401/   705 batches
# Train set | epoch:  12 |    426/   705 batches
# Train set | epoch:  12 |    451/   705 batches
# Train set | epoch:  12 |    476/   705 batches
# Train set | epoch:  12 |    501/   705 batches
# Train set | epoch:  12 |    526/   705 batches
# Train set | epoch:  12 |    551/   705 batches
# Train set | epoch:  12 |    576/   705 batches
# Train set | epoch:  12 |    601/   705 batches
# Train set | epoch:  12 |    626/   705 batches
# Train set | epoch:  12 |    651/   705 batches
# Train set | epoch:  12 |    676/   705 batches
# Train set | epoch:  12 |    701/   705 batches
# Phase:train, epoch loss: 0.0899
# Train set | epoch:  12 |      1/   235 batches
# Train set | epoch:  12 |     26/   235 batches
# Train set | epoch:  12 |     51/   235 batches
# Train set | epoch:  12 |     76/   235 batches
# Train set | epoch:  12 |    101/   235 batches
# Train set | epoch:  12 |    126/   235 batches
# Train set | epoch:  12 |    151/   235 batches
# Train set | epoch:  12 |    176/   235 batches
# Train set | epoch:  12 |    201/   235 batches
# Train set | epoch:  12 |    226/   235 batches
# Phase:validate, epoch loss: 0.0738 | epoch accuracy: 0.0000
# Epoch: 13/99
# ----------
# Train set | epoch:  13 |      1/   705 batches
# Train set | epoch:  13 |     26/   705 batches
# Train set | epoch:  13 |     51/   705 batches
# Train set | epoch:  13 |     76/   705 batches
# Train set | epoch:  13 |    101/   705 batches
# Train set | epoch:  13 |    126/   705 batches
# Train set | epoch:  13 |    151/   705 batches
# Train set | epoch:  13 |    176/   705 batches
# Train set | epoch:  13 |    201/   705 batches
# Train set | epoch:  13 |    226/   705 batches
# Train set | epoch:  13 |    251/   705 batches
# Train set | epoch:  13 |    276/   705 batches
# Train set | epoch:  13 |    301/   705 batches
# Train set | epoch:  13 |    326/   705 batches
# Train set | epoch:  13 |    351/   705 batches
# Train set | epoch:  13 |    376/   705 batches
# Train set | epoch:  13 |    401/   705 batches
# Train set | epoch:  13 |    426/   705 batches
# Train set | epoch:  13 |    451/   705 batches
# Train set | epoch:  13 |    476/   705 batches
# Train set | epoch:  13 |    501/   705 batches
# Train set | epoch:  13 |    526/   705 batches
# Train set | epoch:  13 |    551/   705 batches
# Train set | epoch:  13 |    576/   705 batches
# Train set | epoch:  13 |    601/   705 batches
# Train set | epoch:  13 |    626/   705 batches
# Train set | epoch:  13 |    651/   705 batches
# Train set | epoch:  13 |    676/   705 batches
# Train set | epoch:  13 |    701/   705 batches
# Phase:train, epoch loss: 0.0899
# Train set | epoch:  13 |      1/   235 batches
# Train set | epoch:  13 |     26/   235 batches
# Train set | epoch:  13 |     51/   235 batches
# Train set | epoch:  13 |     76/   235 batches
# Train set | epoch:  13 |    101/   235 batches
# Train set | epoch:  13 |    126/   235 batches
# Train set | epoch:  13 |    151/   235 batches
# Train set | epoch:  13 |    176/   235 batches
# Train set | epoch:  13 |    201/   235 batches
# Train set | epoch:  13 |    226/   235 batches
# Phase:validate, epoch loss: 0.0753 | epoch accuracy: 0.0000
# Epoch: 14/99
# ----------
# Train set | epoch:  14 |      1/   705 batches
# Train set | epoch:  14 |     26/   705 batches
# Train set | epoch:  14 |     51/   705 batches
# Train set | epoch:  14 |     76/   705 batches
# Train set | epoch:  14 |    101/   705 batches
# Train set | epoch:  14 |    126/   705 batches
# Train set | epoch:  14 |    151/   705 batches
# Train set | epoch:  14 |    176/   705 batches
# Train set | epoch:  14 |    201/   705 batches
# Train set | epoch:  14 |    226/   705 batches
# Train set | epoch:  14 |    251/   705 batches
# Train set | epoch:  14 |    276/   705 batches
# Train set | epoch:  14 |    301/   705 batches
# Train set | epoch:  14 |    326/   705 batches
# Train set | epoch:  14 |    351/   705 batches
# Train set | epoch:  14 |    376/   705 batches
# Train set | epoch:  14 |    401/   705 batches
# Train set | epoch:  14 |    426/   705 batches
# Train set | epoch:  14 |    451/   705 batches
# Train set | epoch:  14 |    476/   705 batches
# Train set | epoch:  14 |    501/   705 batches
# Train set | epoch:  14 |    526/   705 batches
# Train set | epoch:  14 |    551/   705 batches
# Train set | epoch:  14 |    576/   705 batches
# Train set | epoch:  14 |    601/   705 batches
# Train set | epoch:  14 |    626/   705 batches
# Train set | epoch:  14 |    651/   705 batches
# Train set | epoch:  14 |    676/   705 batches
# Train set | epoch:  14 |    701/   705 batches
# Phase:train, epoch loss: 0.0899
# Train set | epoch:  14 |      1/   235 batches
# Train set | epoch:  14 |     26/   235 batches
# Train set | epoch:  14 |     51/   235 batches
# Train set | epoch:  14 |     76/   235 batches
# Train set | epoch:  14 |    101/   235 batches
# Train set | epoch:  14 |    126/   235 batches
# Train set | epoch:  14 |    151/   235 batches
# Train set | epoch:  14 |    176/   235 batches
# Train set | epoch:  14 |    201/   235 batches
# Train set | epoch:  14 |    226/   235 batches
# Phase:validate, epoch loss: 0.0757 | epoch accuracy: 0.0000
# Epoch: 15/99
# ----------
# Train set | epoch:  15 |      1/   705 batches
# Train set | epoch:  15 |     26/   705 batches
# Train set | epoch:  15 |     51/   705 batches
# Train set | epoch:  15 |     76/   705 batches
# Train set | epoch:  15 |    101/   705 batches
# Train set | epoch:  15 |    126/   705 batches
# Train set | epoch:  15 |    151/   705 batches
# Train set | epoch:  15 |    176/   705 batches
# Train set | epoch:  15 |    201/   705 batches
# Train set | epoch:  15 |    226/   705 batches
# Train set | epoch:  15 |    251/   705 batches
# Train set | epoch:  15 |    276/   705 batches
# Train set | epoch:  15 |    301/   705 batches
# Train set | epoch:  15 |    326/   705 batches
# Train set | epoch:  15 |    351/   705 batches
# Train set | epoch:  15 |    376/   705 batches
# Train set | epoch:  15 |    401/   705 batches
# Train set | epoch:  15 |    426/   705 batches
# Train set | epoch:  15 |    451/   705 batches
# Train set | epoch:  15 |    476/   705 batches
# Train set | epoch:  15 |    501/   705 batches
# Train set | epoch:  15 |    526/   705 batches
# Train set | epoch:  15 |    551/   705 batches
# Train set | epoch:  15 |    576/   705 batches
# Train set | epoch:  15 |    601/   705 batches
# Train set | epoch:  15 |    626/   705 batches
# Train set | epoch:  15 |    651/   705 batches
# Train set | epoch:  15 |    676/   705 batches
# Train set | epoch:  15 |    701/   705 batches
# Phase:train, epoch loss: 0.0899
# Train set | epoch:  15 |      1/   235 batches
# Train set | epoch:  15 |     26/   235 batches
# Train set | epoch:  15 |     51/   235 batches
# Train set | epoch:  15 |     76/   235 batches
# Train set | epoch:  15 |    101/   235 batches
# Train set | epoch:  15 |    126/   235 batches
# Train set | epoch:  15 |    151/   235 batches
# Train set | epoch:  15 |    176/   235 batches
# Train set | epoch:  15 |    201/   235 batches
# Train set | epoch:  15 |    226/   235 batches
# Phase:validate, epoch loss: 0.1672 | epoch accuracy: 0.0000
# Epoch: 16/99
# ----------
# Train set | epoch:  16 |      1/   705 batches
# Train set | epoch:  16 |     26/   705 batches
# Train set | epoch:  16 |     51/   705 batches
# Train set | epoch:  16 |     76/   705 batches
# Train set | epoch:  16 |    101/   705 batches
# Train set | epoch:  16 |    126/   705 batches
# Train set | epoch:  16 |    151/   705 batches
# Train set | epoch:  16 |    176/   705 batches
# Train set | epoch:  16 |    201/   705 batches
# Train set | epoch:  16 |    226/   705 batches
# Train set | epoch:  16 |    251/   705 batches
# Train set | epoch:  16 |    276/   705 batches
# Train set | epoch:  16 |    301/   705 batches
# Train set | epoch:  16 |    326/   705 batches
# Train set | epoch:  16 |    351/   705 batches
# Train set | epoch:  16 |    376/   705 batches
# Train set | epoch:  16 |    401/   705 batches
# Train set | epoch:  16 |    426/   705 batches
# Train set | epoch:  16 |    451/   705 batches
# Train set | epoch:  16 |    476/   705 batches
# Train set | epoch:  16 |    501/   705 batches
# Train set | epoch:  16 |    526/   705 batches
# Train set | epoch:  16 |    551/   705 batches
# Train set | epoch:  16 |    576/   705 batches
# Train set | epoch:  16 |    601/   705 batches
# Train set | epoch:  16 |    626/   705 batches
# Train set | epoch:  16 |    651/   705 batches
# Train set | epoch:  16 |    676/   705 batches
# Train set | epoch:  16 |    701/   705 batches
# Phase:train, epoch loss: 0.0899
# Train set | epoch:  16 |      1/   235 batches
# Train set | epoch:  16 |     26/   235 batches
# Train set | epoch:  16 |     51/   235 batches
# Train set | epoch:  16 |     76/   235 batches
# Train set | epoch:  16 |    101/   235 batches
# Train set | epoch:  16 |    126/   235 batches
# Train set | epoch:  16 |    151/   235 batches
# Train set | epoch:  16 |    176/   235 batches
# Train set | epoch:  16 |    201/   235 batches
# Train set | epoch:  16 |    226/   235 batches
# Phase:validate, epoch loss: 0.0723 | epoch accuracy: 0.0000
# Epoch: 17/99
# ----------
# Train set | epoch:  17 |      1/   705 batches
# Train set | epoch:  17 |     26/   705 batches
# Train set | epoch:  17 |     51/   705 batches
# Train set | epoch:  17 |     76/   705 batches
# Train set | epoch:  17 |    101/   705 batches
# Train set | epoch:  17 |    126/   705 batches
# Train set | epoch:  17 |    151/   705 batches
# Train set | epoch:  17 |    176/   705 batches
# Train set | epoch:  17 |    201/   705 batches
# Train set | epoch:  17 |    226/   705 batches
# Train set | epoch:  17 |    251/   705 batches
# Train set | epoch:  17 |    276/   705 batches
# Train set | epoch:  17 |    301/   705 batches
# Train set | epoch:  17 |    326/   705 batches
# Train set | epoch:  17 |    351/   705 batches
# Train set | epoch:  17 |    376/   705 batches
# Train set | epoch:  17 |    401/   705 batches
# Train set | epoch:  17 |    426/   705 batches
# Train set | epoch:  17 |    451/   705 batches
# Train set | epoch:  17 |    476/   705 batches
# Train set | epoch:  17 |    501/   705 batches
# Train set | epoch:  17 |    526/   705 batches
# Train set | epoch:  17 |    551/   705 batches
# Train set | epoch:  17 |    576/   705 batches
# Train set | epoch:  17 |    601/   705 batches
# Train set | epoch:  17 |    626/   705 batches
# Train set | epoch:  17 |    651/   705 batches
# Train set | epoch:  17 |    676/   705 batches
# Train set | epoch:  17 |    701/   705 batches
# Phase:train, epoch loss: 0.0900
# Train set | epoch:  17 |      1/   235 batches
# Train set | epoch:  17 |     26/   235 batches
# Train set | epoch:  17 |     51/   235 batches
# Train set | epoch:  17 |     76/   235 batches
# Train set | epoch:  17 |    101/   235 batches
# Train set | epoch:  17 |    126/   235 batches
# Train set | epoch:  17 |    151/   235 batches
# Train set | epoch:  17 |    176/   235 batches
# Train set | epoch:  17 |    201/   235 batches
# Train set | epoch:  17 |    226/   235 batches
# Phase:validate, epoch loss: 0.0765 | epoch accuracy: 0.0000
# Epoch: 18/99
# ----------
# Train set | epoch:  18 |      1/   705 batches
# Train set | epoch:  18 |     26/   705 batches
# Train set | epoch:  18 |     51/   705 batches
# Train set | epoch:  18 |     76/   705 batches
# Train set | epoch:  18 |    101/   705 batches
# Train set | epoch:  18 |    126/   705 batches
# Train set | epoch:  18 |    151/   705 batches
# Train set | epoch:  18 |    176/   705 batches
# Train set | epoch:  18 |    201/   705 batches
# Train set | epoch:  18 |    226/   705 batches
# Train set | epoch:  18 |    251/   705 batches
# Train set | epoch:  18 |    276/   705 batches
# Train set | epoch:  18 |    301/   705 batches
# Train set | epoch:  18 |    326/   705 batches
# Train set | epoch:  18 |    351/   705 batches
# Train set | epoch:  18 |    376/   705 batches
# Train set | epoch:  18 |    401/   705 batches
# Train set | epoch:  18 |    426/   705 batches
# Train set | epoch:  18 |    451/   705 batches
# Train set | epoch:  18 |    476/   705 batches
# Train set | epoch:  18 |    501/   705 batches
# Train set | epoch:  18 |    526/   705 batches
# Train set | epoch:  18 |    551/   705 batches
# Train set | epoch:  18 |    576/   705 batches
# Train set | epoch:  18 |    601/   705 batches
# Train set | epoch:  18 |    626/   705 batches
# Train set | epoch:  18 |    651/   705 batches
# Train set | epoch:  18 |    676/   705 batches
# Train set | epoch:  18 |    701/   705 batches
# Phase:train, epoch loss: 0.0898
# Train set | epoch:  18 |      1/   235 batches
# Train set | epoch:  18 |     26/   235 batches
# Train set | epoch:  18 |     51/   235 batches
# Train set | epoch:  18 |     76/   235 batches
# Train set | epoch:  18 |    101/   235 batches
# Train set | epoch:  18 |    126/   235 batches
# Train set | epoch:  18 |    151/   235 batches
# Train set | epoch:  18 |    176/   235 batches
# Train set | epoch:  18 |    201/   235 batches
# Train set | epoch:  18 |    226/   235 batches
# Phase:validate, epoch loss: 0.0712 | epoch accuracy: 0.0000
# Epoch: 19/99
# ----------
# Train set | epoch:  19 |      1/   705 batches
# Train set | epoch:  19 |     26/   705 batches
# Train set | epoch:  19 |     51/   705 batches
# Train set | epoch:  19 |     76/   705 batches
# Train set | epoch:  19 |    101/   705 batches
# Train set | epoch:  19 |    126/   705 batches
# Train set | epoch:  19 |    151/   705 batches
# Train set | epoch:  19 |    176/   705 batches
# Train set | epoch:  19 |    201/   705 batches
# Train set | epoch:  19 |    226/   705 batches
# Train set | epoch:  19 |    251/   705 batches
# Train set | epoch:  19 |    276/   705 batches
# Train set | epoch:  19 |    301/   705 batches
# Train set | epoch:  19 |    326/   705 batches
# Train set | epoch:  19 |    351/   705 batches
# Train set | epoch:  19 |    376/   705 batches
# Train set | epoch:  19 |    401/   705 batches
# Train set | epoch:  19 |    426/   705 batches
# Train set | epoch:  19 |    451/   705 batches
# Train set | epoch:  19 |    476/   705 batches
# Train set | epoch:  19 |    501/   705 batches
# Train set | epoch:  19 |    526/   705 batches
# Train set | epoch:  19 |    551/   705 batches
# Train set | epoch:  19 |    576/   705 batches
# Train set | epoch:  19 |    601/   705 batches
# Train set | epoch:  19 |    626/   705 batches
# Train set | epoch:  19 |    651/   705 batches
# Train set | epoch:  19 |    676/   705 batches
# Train set | epoch:  19 |    701/   705 batches
# Phase:train, epoch loss: 0.0898
# Train set | epoch:  19 |      1/   235 batches
# Train set | epoch:  19 |     26/   235 batches
# Train set | epoch:  19 |     51/   235 batches
# Train set | epoch:  19 |     76/   235 batches
# Train set | epoch:  19 |    101/   235 batches
# Train set | epoch:  19 |    126/   235 batches
# Train set | epoch:  19 |    151/   235 batches
# Train set | epoch:  19 |    176/   235 batches
# Train set | epoch:  19 |    201/   235 batches
# Train set | epoch:  19 |    226/   235 batches
# Phase:validate, epoch loss: 0.0757 | epoch accuracy: 0.0000
# Epoch: 20/99
# ----------
# Train set | epoch:  20 |      1/   705 batches
# Train set | epoch:  20 |     26/   705 batches
# Train set | epoch:  20 |     51/   705 batches
# Train set | epoch:  20 |     76/   705 batches
# Train set | epoch:  20 |    101/   705 batches
# Train set | epoch:  20 |    126/   705 batches
# Train set | epoch:  20 |    151/   705 batches
# Train set | epoch:  20 |    176/   705 batches
# Train set | epoch:  20 |    201/   705 batches
# Train set | epoch:  20 |    226/   705 batches
# Train set | epoch:  20 |    251/   705 batches
# Train set | epoch:  20 |    276/   705 batches
# Train set | epoch:  20 |    301/   705 batches
# Train set | epoch:  20 |    326/   705 batches
# Train set | epoch:  20 |    351/   705 batches
# Train set | epoch:  20 |    376/   705 batches
# Train set | epoch:  20 |    401/   705 batches
# Train set | epoch:  20 |    426/   705 batches
# Train set | epoch:  20 |    451/   705 batches
# Train set | epoch:  20 |    476/   705 batches
# Train set | epoch:  20 |    501/   705 batches
# Train set | epoch:  20 |    526/   705 batches
# Train set | epoch:  20 |    551/   705 batches
# Train set | epoch:  20 |    576/   705 batches
# Train set | epoch:  20 |    601/   705 batches
# Train set | epoch:  20 |    626/   705 batches
# Train set | epoch:  20 |    651/   705 batches
# Train set | epoch:  20 |    676/   705 batches
# Train set | epoch:  20 |    701/   705 batches
# Phase:train, epoch loss: 0.0899
# Train set | epoch:  20 |      1/   235 batches
# Train set | epoch:  20 |     26/   235 batches
# Train set | epoch:  20 |     51/   235 batches
# Train set | epoch:  20 |     76/   235 batches
# Train set | epoch:  20 |    101/   235 batches
# Train set | epoch:  20 |    126/   235 batches
# Train set | epoch:  20 |    151/   235 batches
# Train set | epoch:  20 |    176/   235 batches
# Train set | epoch:  20 |    201/   235 batches
# Train set | epoch:  20 |    226/   235 batches
# Phase:validate, epoch loss: 0.0715 | epoch accuracy: 0.0000
# Epoch: 21/99
# ----------
# Train set | epoch:  21 |      1/   705 batches
# Train set | epoch:  21 |     26/   705 batches
# Train set | epoch:  21 |     51/   705 batches
# Train set | epoch:  21 |     76/   705 batches
# Train set | epoch:  21 |    101/   705 batches
# Train set | epoch:  21 |    126/   705 batches
# Train set | epoch:  21 |    151/   705 batches
# Train set | epoch:  21 |    176/   705 batches
# Train set | epoch:  21 |    201/   705 batches
# Train set | epoch:  21 |    226/   705 batches
# Train set | epoch:  21 |    251/   705 batches
# Train set | epoch:  21 |    276/   705 batches
# Train set | epoch:  21 |    301/   705 batches
# Train set | epoch:  21 |    326/   705 batches
# Train set | epoch:  21 |    351/   705 batches
# Train set | epoch:  21 |    376/   705 batches
# Train set | epoch:  21 |    401/   705 batches
# Train set | epoch:  21 |    426/   705 batches
# Train set | epoch:  21 |    451/   705 batches
# Train set | epoch:  21 |    476/   705 batches
# Train set | epoch:  21 |    501/   705 batches
# Train set | epoch:  21 |    526/   705 batches
# Train set | epoch:  21 |    551/   705 batches
# Train set | epoch:  21 |    576/   705 batches
# Train set | epoch:  21 |    601/   705 batches
# Train set | epoch:  21 |    626/   705 batches
# Train set | epoch:  21 |    651/   705 batches
# Train set | epoch:  21 |    676/   705 batches
# Train set | epoch:  21 |    701/   705 batches
# Phase:train, epoch loss: 0.0900
# Train set | epoch:  21 |      1/   235 batches
# Train set | epoch:  21 |     26/   235 batches
# Train set | epoch:  21 |     51/   235 batches
# Train set | epoch:  21 |     76/   235 batches
# Train set | epoch:  21 |    101/   235 batches
# Train set | epoch:  21 |    126/   235 batches
# Train set | epoch:  21 |    151/   235 batches
# Train set | epoch:  21 |    176/   235 batches
# Train set | epoch:  21 |    201/   235 batches
# Train set | epoch:  21 |    226/   235 batches
# Phase:validate, epoch loss: 0.2653 | epoch accuracy: 0.0000
# Epoch: 22/99
# ----------
# Train set | epoch:  22 |      1/   705 batches
# Train set | epoch:  22 |     26/   705 batches
# Train set | epoch:  22 |     51/   705 batches
# Train set | epoch:  22 |     76/   705 batches
# Train set | epoch:  22 |    101/   705 batches
# Train set | epoch:  22 |    126/   705 batches
# Train set | epoch:  22 |    151/   705 batches
# Train set | epoch:  22 |    176/   705 batches
# Train set | epoch:  22 |    201/   705 batches
# Train set | epoch:  22 |    226/   705 batches
# Train set | epoch:  22 |    251/   705 batches
# Train set | epoch:  22 |    276/   705 batches
# Train set | epoch:  22 |    301/   705 batches
# Train set | epoch:  22 |    326/   705 batches
# Train set | epoch:  22 |    351/   705 batches
# Train set | epoch:  22 |    376/   705 batches
# Train set | epoch:  22 |    401/   705 batches
# Train set | epoch:  22 |    426/   705 batches
# Train set | epoch:  22 |    451/   705 batches
# Train set | epoch:  22 |    476/   705 batches
# Train set | epoch:  22 |    501/   705 batches
# Train set | epoch:  22 |    526/   705 batches
# Train set | epoch:  22 |    551/   705 batches
# Train set | epoch:  22 |    576/   705 batches
# Train set | epoch:  22 |    601/   705 batches
# Train set | epoch:  22 |    626/   705 batches
# Train set | epoch:  22 |    651/   705 batches
# Train set | epoch:  22 |    676/   705 batches
# Train set | epoch:  22 |    701/   705 batches
# Phase:train, epoch loss: 0.0899
# Train set | epoch:  22 |      1/   235 batches
# Train set | epoch:  22 |     26/   235 batches
# Train set | epoch:  22 |     51/   235 batches
# Train set | epoch:  22 |     76/   235 batches
# Train set | epoch:  22 |    101/   235 batches
# Train set | epoch:  22 |    126/   235 batches
# Train set | epoch:  22 |    151/   235 batches
# Train set | epoch:  22 |    176/   235 batches
# Train set | epoch:  22 |    201/   235 batches
# Train set | epoch:  22 |    226/   235 batches
# Phase:validate, epoch loss: 0.0731 | epoch accuracy: 0.0000
# Epoch: 23/99
# ----------
# Train set | epoch:  23 |      1/   705 batches
# Train set | epoch:  23 |     26/   705 batches
# Train set | epoch:  23 |     51/   705 batches
# Train set | epoch:  23 |     76/   705 batches
# Train set | epoch:  23 |    101/   705 batches
# Train set | epoch:  23 |    126/   705 batches
# Train set | epoch:  23 |    151/   705 batches
# Train set | epoch:  23 |    176/   705 batches
# Train set | epoch:  23 |    201/   705 batches
# Train set | epoch:  23 |    226/   705 batches
# Train set | epoch:  23 |    251/   705 batches
# Train set | epoch:  23 |    276/   705 batches
# Train set | epoch:  23 |    301/   705 batches
# Train set | epoch:  23 |    326/   705 batches
# Train set | epoch:  23 |    351/   705 batches
# Train set | epoch:  23 |    376/   705 batches
# Train set | epoch:  23 |    401/   705 batches
# Train set | epoch:  23 |    426/   705 batches
# Train set | epoch:  23 |    451/   705 batches
# Train set | epoch:  23 |    476/   705 batches
# Train set | epoch:  23 |    501/   705 batches
# Train set | epoch:  23 |    526/   705 batches
# Train set | epoch:  23 |    551/   705 batches
# Train set | epoch:  23 |    576/   705 batches
# Train set | epoch:  23 |    601/   705 batches
# Train set | epoch:  23 |    626/   705 batches
# Train set | epoch:  23 |    651/   705 batches
# Train set | epoch:  23 |    676/   705 batches
# Train set | epoch:  23 |    701/   705 batches
# Phase:train, epoch loss: 0.0899
# Train set | epoch:  23 |      1/   235 batches
# Train set | epoch:  23 |     26/   235 batches
# Train set | epoch:  23 |     51/   235 batches
# Train set | epoch:  23 |     76/   235 batches
# Train set | epoch:  23 |    101/   235 batches
# Train set | epoch:  23 |    126/   235 batches
# Train set | epoch:  23 |    151/   235 batches
# Train set | epoch:  23 |    176/   235 batches
# Train set | epoch:  23 |    201/   235 batches
# Train set | epoch:  23 |    226/   235 batches
# Phase:validate, epoch loss: 0.0723 | epoch accuracy: 0.0000
# Epoch: 24/99
# ----------
# Train set | epoch:  24 |      1/   705 batches
# Train set | epoch:  24 |     26/   705 batches
# Train set | epoch:  24 |     51/   705 batches
# Train set | epoch:  24 |     76/   705 batches
# Train set | epoch:  24 |    101/   705 batches
# Train set | epoch:  24 |    126/   705 batches
# Train set | epoch:  24 |    151/   705 batches
# Train set | epoch:  24 |    176/   705 batches
# Train set | epoch:  24 |    201/   705 batches
# Train set | epoch:  24 |    226/   705 batches
# Train set | epoch:  24 |    251/   705 batches
# Train set | epoch:  24 |    276/   705 batches
# Train set | epoch:  24 |    301/   705 batches
# Train set | epoch:  24 |    326/   705 batches
# Train set | epoch:  24 |    351/   705 batches
# Train set | epoch:  24 |    376/   705 batches
# Train set | epoch:  24 |    401/   705 batches
# Train set | epoch:  24 |    426/   705 batches
# Train set | epoch:  24 |    451/   705 batches
# Train set | epoch:  24 |    476/   705 batches
# Train set | epoch:  24 |    501/   705 batches
# Train set | epoch:  24 |    526/   705 batches
# Train set | epoch:  24 |    551/   705 batches
# Train set | epoch:  24 |    576/   705 batches
# Train set | epoch:  24 |    601/   705 batches
# ...
# Train set | epoch:  70 |    201/   235 batches
# Train set | epoch:  70 |    226/   235 batches
# Phase:validate, epoch loss: 0.0892 | epoch accuracy: 0.0000
# Epoch: 71/99
# ----------
# Train set | epoch:  71 |      1/   705 batches
# Train set | epoch:  71 |     26/   705 batches
# Train set | epoch:  71 |     51/   705 batches
# Train set | epoch:  71 |     76/   705 batches
# Train set | epoch:  71 |    101/   705 batches
# Train set | epoch:  71 |    126/   705 batches
# Train set | epoch:  71 |    151/   705 batches
# Train set | epoch:  71 |    176/   705 batches
# Train set | epoch:  71 |    201/   705 batches
# Train set | epoch:  71 |    226/   705 batches
# Train set | epoch:  71 |    251/   705 batches
# Train set | epoch:  71 |    276/   705 batches
# Train set | epoch:  71 |    301/   705 batches
# Train set | epoch:  71 |    326/   705 batches
# Train set | epoch:  71 |    351/   705 batches
# Train set | epoch:  71 |    376/   705 batches
# Train set | epoch:  71 |    401/   705 batches
# Train set | epoch:  71 |    426/   705 batches
# Train set | epoch:  71 |    451/   705 batches
# Train set | epoch:  71 |    476/   705 batches
# Train set | epoch:  71 |    501/   705 batches
# Train set | epoch:  71 |    526/   705 batches
# Train set | epoch:  71 |    551/   705 batches
# Train set | epoch:  71 |    576/   705 batches
# Train set | epoch:  71 |    601/   705 batches
# Train set | epoch:  71 |    626/   705 batches
# Train set | epoch:  71 |    651/   705 batches
# Train set | epoch:  71 |    676/   705 batches
# Train set | epoch:  71 |    701/   705 batches
# Phase:train, epoch loss: 0.0899
# Train set | epoch:  71 |      1/   235 batches
# Train set | epoch:  71 |     26/   235 batches
# Train set | epoch:  71 |     51/   235 batches
# Train set | epoch:  71 |     76/   235 batches
# Train set | epoch:  71 |    101/   235 batches
# Train set | epoch:  71 |    126/   235 batches
# Train set | epoch:  71 |    151/   235 batches
# Train set | epoch:  71 |    176/   235 batches
# Train set | epoch:  71 |    201/   235 batches
# Train set | epoch:  71 |    226/   235 batches
# Phase:validate, epoch loss: 0.0730 | epoch accuracy: 0.0000
# Epoch: 72/99
# ----------
# Train set | epoch:  72 |      1/   705 batches
# Train set | epoch:  72 |     26/   705 batches
# Train set | epoch:  72 |     51/   705 batches
# Train set | epoch:  72 |     76/   705 batches
# Train set | epoch:  72 |    101/   705 batches
# Train set | epoch:  72 |    126/   705 batches
# Train set | epoch:  72 |    151/   705 batches
# Train set | epoch:  72 |    176/   705 batches
# Train set | epoch:  72 |    201/   705 batches
# Train set | epoch:  72 |    226/   705 batches
# Train set | epoch:  72 |    251/   705 batches
# Train set | epoch:  72 |    276/   705 batches
# Train set | epoch:  72 |    301/   705 batches
# Train set | epoch:  72 |    326/   705 batches
# Train set | epoch:  72 |    351/   705 batches
# Train set | epoch:  72 |    376/   705 batches
# Train set | epoch:  72 |    401/   705 batches
# Train set | epoch:  72 |    426/   705 batches
# Train set | epoch:  72 |    451/   705 batches
# Train set | epoch:  72 |    476/   705 batches
# Train set | epoch:  72 |    501/   705 batches
# Train set | epoch:  72 |    526/   705 batches
# Train set | epoch:  72 |    551/   705 batches
# Train set | epoch:  72 |    576/   705 batches
# Train set | epoch:  72 |    601/   705 batches
# Train set | epoch:  72 |    626/   705 batches
# Train set | epoch:  72 |    651/   705 batches
# Train set | epoch:  72 |    676/   705 batches
# Train set | epoch:  72 |    701/   705 batches
# Phase:train, epoch loss: 0.0898
# Train set | epoch:  72 |      1/   235 batches
# Train set | epoch:  72 |     26/   235 batches
# Train set | epoch:  72 |     51/   235 batches
# Train set | epoch:  72 |     76/   235 batches
# Train set | epoch:  72 |    101/   235 batches
# Train set | epoch:  72 |    126/   235 batches
# Train set | epoch:  72 |    151/   235 batches
# Train set | epoch:  72 |    176/   235 batches
# Train set | epoch:  72 |    201/   235 batches
# Train set | epoch:  72 |    226/   235 batches
# Phase:validate, epoch loss: 0.0699 | epoch accuracy: 0.0000
# Epoch: 73/99
# ----------
# Train set | epoch:  73 |      1/   705 batches
# Train set | epoch:  73 |     26/   705 batches
# Train set | epoch:  73 |     51/   705 batches
# Train set | epoch:  73 |     76/   705 batches
# Train set | epoch:  73 |    101/   705 batches
# Train set | epoch:  73 |    126/   705 batches
# Train set | epoch:  73 |    151/   705 batches
# Train set | epoch:  73 |    176/   705 batches
# Train set | epoch:  73 |    201/   705 batches
# Train set | epoch:  73 |    226/   705 batches
# Train set | epoch:  73 |    251/   705 batches
# Train set | epoch:  73 |    276/   705 batches
# Train set | epoch:  73 |    301/   705 batches
# Train set | epoch:  73 |    326/   705 batches
# Train set | epoch:  73 |    351/   705 batches
# Train set | epoch:  73 |    376/   705 batches
# Train set | epoch:  73 |    401/   705 batches
# Train set | epoch:  73 |    426/   705 batches
# Train set | epoch:  73 |    451/   705 batches
# Train set | epoch:  73 |    476/   705 batches
# Train set | epoch:  73 |    501/   705 batches
# Train set | epoch:  73 |    526/   705 batches
# Train set | epoch:  73 |    551/   705 batches
# Train set | epoch:  73 |    576/   705 batches
# Train set | epoch:  73 |    601/   705 batches
# Train set | epoch:  73 |    626/   705 batches
# Train set | epoch:  73 |    651/   705 batches
# Train set | epoch:  73 |    676/   705 batches
# Train set | epoch:  73 |    701/   705 batches
# Phase:train, epoch loss: 0.0899
# Train set | epoch:  73 |      1/   235 batches
# Train set | epoch:  73 |     26/   235 batches
# Train set | epoch:  73 |     51/   235 batches
# Train set | epoch:  73 |     76/   235 batches
# Train set | epoch:  73 |    101/   235 batches
# Train set | epoch:  73 |    126/   235 batches
# Train set | epoch:  73 |    151/   235 batches
# Train set | epoch:  73 |    176/   235 batches
# Train set | epoch:  73 |    201/   235 batches
# Train set | epoch:  73 |    226/   235 batches
# Phase:validate, epoch loss: 0.1970 | epoch accuracy: 0.0000
# Epoch: 74/99
# ----------
# Train set | epoch:  74 |      1/   705 batches
# Train set | epoch:  74 |     26/   705 batches
# Train set | epoch:  74 |     51/   705 batches
# Train set | epoch:  74 |     76/   705 batches
# Train set | epoch:  74 |    101/   705 batches
# Train set | epoch:  74 |    126/   705 batches
# Train set | epoch:  74 |    151/   705 batches
# Train set | epoch:  74 |    176/   705 batches
# Train set | epoch:  74 |    201/   705 batches
# Train set | epoch:  74 |    226/   705 batches
# Train set | epoch:  74 |    251/   705 batches
# Train set | epoch:  74 |    276/   705 batches
# Train set | epoch:  74 |    301/   705 batches
# Train set | epoch:  74 |    326/   705 batches
# Train set | epoch:  74 |    351/   705 batches
# Train set | epoch:  74 |    376/   705 batches
# Train set | epoch:  74 |    401/   705 batches
# Train set | epoch:  74 |    426/   705 batches
# Train set | epoch:  74 |    451/   705 batches
# Train set | epoch:  74 |    476/   705 batches
# Train set | epoch:  74 |    501/   705 batches
# Train set | epoch:  74 |    526/   705 batches
# Train set | epoch:  74 |    551/   705 batches
# Train set | epoch:  74 |    576/   705 batches
# Train set | epoch:  74 |    601/   705 batches
# Train set | epoch:  74 |    626/   705 batches
# Train set | epoch:  74 |    651/   705 batches
# Train set | epoch:  74 |    676/   705 batches
# Train set | epoch:  74 |    701/   705 batches
# Phase:train, epoch loss: 0.0899
# Train set | epoch:  74 |      1/   235 batches
# Train set | epoch:  74 |     26/   235 batches
# Train set | epoch:  74 |     51/   235 batches
# Train set | epoch:  74 |     76/   235 batches
# Train set | epoch:  74 |    101/   235 batches
# Train set | epoch:  74 |    126/   235 batches
# Train set | epoch:  74 |    151/   235 batches
# Train set | epoch:  74 |    176/   235 batches
# Train set | epoch:  74 |    201/   235 batches
# Train set | epoch:  74 |    226/   235 batches
# Phase:validate, epoch loss: 0.0773 | epoch accuracy: 0.0000
# Epoch: 75/99
# ----------
# Train set | epoch:  75 |      1/   705 batches
# Train set | epoch:  75 |     26/   705 batches
# Train set | epoch:  75 |     51/   705 batches
# Train set | epoch:  75 |     76/   705 batches
# Train set | epoch:  75 |    101/   705 batches
# Train set | epoch:  75 |    126/   705 batches
# Train set | epoch:  75 |    151/   705 batches
# Train set | epoch:  75 |    176/   705 batches
# Train set | epoch:  75 |    201/   705 batches
# Train set | epoch:  75 |    226/   705 batches
# Train set | epoch:  75 |    251/   705 batches
# Train set | epoch:  75 |    276/   705 batches
# Train set | epoch:  75 |    301/   705 batches
# Train set | epoch:  75 |    326/   705 batches
# Train set | epoch:  75 |    351/   705 batches
# Train set | epoch:  75 |    376/   705 batches
# Train set | epoch:  75 |    401/   705 batches
# Train set | epoch:  75 |    426/   705 batches
# Train set | epoch:  75 |    451/   705 batches
# Train set | epoch:  75 |    476/   705 batches
# Train set | epoch:  75 |    501/   705 batches
# Train set | epoch:  75 |    526/   705 batches
# Train set | epoch:  75 |    551/   705 batches
# Train set | epoch:  75 |    576/   705 batches
# Train set | epoch:  75 |    601/   705 batches
# Train set | epoch:  75 |    626/   705 batches
# Train set | epoch:  75 |    651/   705 batches
# Train set | epoch:  75 |    676/   705 batches
# Train set | epoch:  75 |    701/   705 batches
# Phase:train, epoch loss: 0.0898
# Train set | epoch:  75 |      1/   235 batches
# Train set | epoch:  75 |     26/   235 batches
# Train set | epoch:  75 |     51/   235 batches
# Train set | epoch:  75 |     76/   235 batches
# Train set | epoch:  75 |    101/   235 batches
# Train set | epoch:  75 |    126/   235 batches
# Train set | epoch:  75 |    151/   235 batches
# Train set | epoch:  75 |    176/   235 batches
# Train set | epoch:  75 |    201/   235 batches
# Train set | epoch:  75 |    226/   235 batches
# Phase:validate, epoch loss: 0.0954 | epoch accuracy: 0.0000
# Epoch: 76/99
# ----------
# Train set | epoch:  76 |      1/   705 batches
# Train set | epoch:  76 |     26/   705 batches
# Train set | epoch:  76 |     51/   705 batches
# Train set | epoch:  76 |     76/   705 batches
# Train set | epoch:  76 |    101/   705 batches
# Train set | epoch:  76 |    126/   705 batches
# Train set | epoch:  76 |    151/   705 batches
# Train set | epoch:  76 |    176/   705 batches
# Train set | epoch:  76 |    201/   705 batches
# Train set | epoch:  76 |    226/   705 batches
# Train set | epoch:  76 |    251/   705 batches
# Train set | epoch:  76 |    276/   705 batches
# Train set | epoch:  76 |    301/   705 batches
# Train set | epoch:  76 |    326/   705 batches
# Train set | epoch:  76 |    351/   705 batches
# Train set | epoch:  76 |    376/   705 batches
# Train set | epoch:  76 |    401/   705 batches
# Train set | epoch:  76 |    426/   705 batches
# Train set | epoch:  76 |    451/   705 batches
# Train set | epoch:  76 |    476/   705 batches
# Train set | epoch:  76 |    501/   705 batches
# Train set | epoch:  76 |    526/   705 batches
# Train set | epoch:  76 |    551/   705 batches
# Train set | epoch:  76 |    576/   705 batches
# Train set | epoch:  76 |    601/   705 batches
# Train set | epoch:  76 |    626/   705 batches
# Train set | epoch:  76 |    651/   705 batches
# Train set | epoch:  76 |    676/   705 batches
# Train set | epoch:  76 |    701/   705 batches
# Phase:train, epoch loss: 0.0899
# Train set | epoch:  76 |      1/   235 batches
# Train set | epoch:  76 |     26/   235 batches
# Train set | epoch:  76 |     51/   235 batches
# Train set | epoch:  76 |     76/   235 batches
# Train set | epoch:  76 |    101/   235 batches
# Train set | epoch:  76 |    126/   235 batches
# Train set | epoch:  76 |    151/   235 batches
# Train set | epoch:  76 |    176/   235 batches
# Train set | epoch:  76 |    201/   235 batches
# Train set | epoch:  76 |    226/   235 batches
# Phase:validate, epoch loss: 0.0854 | epoch accuracy: 0.0000
# Epoch: 77/99
# ----------
# Train set | epoch:  77 |      1/   705 batches
# Train set | epoch:  77 |     26/   705 batches
# Train set | epoch:  77 |     51/   705 batches
# Train set | epoch:  77 |     76/   705 batches
# Train set | epoch:  77 |    101/   705 batches
# Train set | epoch:  77 |    126/   705 batches
# Train set | epoch:  77 |    151/   705 batches
# Train set | epoch:  77 |    176/   705 batches
# Train set | epoch:  77 |    201/   705 batches
# Train set | epoch:  77 |    226/   705 batches
# Train set | epoch:  77 |    251/   705 batches
# Train set | epoch:  77 |    276/   705 batches
# Train set | epoch:  77 |    301/   705 batches
# Train set | epoch:  77 |    326/   705 batches
# Train set | epoch:  77 |    351/   705 batches
# Train set | epoch:  77 |    376/   705 batches
# Train set | epoch:  77 |    401/   705 batches
# Train set | epoch:  77 |    426/   705 batches
# Train set | epoch:  77 |    451/   705 batches
# Train set | epoch:  77 |    476/   705 batches
# Train set | epoch:  77 |    501/   705 batches
# Train set | epoch:  77 |    526/   705 batches
# Train set | epoch:  77 |    551/   705 batches
# Train set | epoch:  77 |    576/   705 batches
# Train set | epoch:  77 |    601/   705 batches
# Train set | epoch:  77 |    626/   705 batches
# Train set | epoch:  77 |    651/   705 batches
# Train set | epoch:  77 |    676/   705 batches
# Train set | epoch:  77 |    701/   705 batches
# Phase:train, epoch loss: 0.0899
# Train set | epoch:  77 |      1/   235 batches
# Train set | epoch:  77 |     26/   235 batches
# Train set | epoch:  77 |     51/   235 batches
# Train set | epoch:  77 |     76/   235 batches
# Train set | epoch:  77 |    101/   235 batches
# Train set | epoch:  77 |    126/   235 batches
# Train set | epoch:  77 |    151/   235 batches
# Train set | epoch:  77 |    176/   235 batches
# Train set | epoch:  77 |    201/   235 batches
# Train set | epoch:  77 |    226/   235 batches
# Phase:validate, epoch loss: 0.0714 | epoch accuracy: 0.0000
# Epoch: 78/99
# ----------
# Train set | epoch:  78 |      1/   705 batches
# Train set | epoch:  78 |     26/   705 batches
# Train set | epoch:  78 |     51/   705 batches
# Train set | epoch:  78 |     76/   705 batches
# Train set | epoch:  78 |    101/   705 batches
# Train set | epoch:  78 |    126/   705 batches
# Train set | epoch:  78 |    151/   705 batches
# Train set | epoch:  78 |    176/   705 batches
# Train set | epoch:  78 |    201/   705 batches
# Train set | epoch:  78 |    226/   705 batches
# Train set | epoch:  78 |    251/   705 batches
# Train set | epoch:  78 |    276/   705 batches
# Train set | epoch:  78 |    301/   705 batches
# Train set | epoch:  78 |    326/   705 batches
# Train set | epoch:  78 |    351/   705 batches
# Train set | epoch:  78 |    376/   705 batches
# Train set | epoch:  78 |    401/   705 batches
# Train set | epoch:  78 |    426/   705 batches
# Train set | epoch:  78 |    451/   705 batches
# Train set | epoch:  78 |    476/   705 batches
# Train set | epoch:  78 |    501/   705 batches
# Train set | epoch:  78 |    526/   705 batches
# Train set | epoch:  78 |    551/   705 batches
# Train set | epoch:  78 |    576/   705 batches
# Train set | epoch:  78 |    601/   705 batches
# Train set | epoch:  78 |    626/   705 batches
# Train set | epoch:  78 |    651/   705 batches
# Train set | epoch:  78 |    676/   705 batches
# Train set | epoch:  78 |    701/   705 batches
# Phase:train, epoch loss: 0.0899
# Train set | epoch:  78 |      1/   235 batches
# Train set | epoch:  78 |     26/   235 batches
# Train set | epoch:  78 |     51/   235 batches
# Train set | epoch:  78 |     76/   235 batches
# Train set | epoch:  78 |    101/   235 batches
# Train set | epoch:  78 |    126/   235 batches
# Train set | epoch:  78 |    151/   235 batches
# Train set | epoch:  78 |    176/   235 batches
# Train set | epoch:  78 |    201/   235 batches
# Train set | epoch:  78 |    226/   235 batches
# Phase:validate, epoch loss: 0.0736 | epoch accuracy: 0.0000
# Epoch: 79/99
# ----------
# Train set | epoch:  79 |      1/   705 batches
# Train set | epoch:  79 |     26/   705 batches
# Train set | epoch:  79 |     51/   705 batches
# Train set | epoch:  79 |     76/   705 batches

# %%
plt.plot(epochLossTrain, label = "Epoch Train Loss")
plt.plot(epochLossValidate, label = "Epoch Validate Loss")
plt.legend(loc = "upper right")

# %%
# plt.plot(epochLossTrain, label = "Epoch Train Loss")
plt.plot(epochAccValidate, label = "Epoch Accuracy")
plt.legend(loc = "upper right")
